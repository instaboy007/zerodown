# %%
import pandas as pd
import firebase_admin
from firebase_admin import credentials

dataSet=pd.read_csv('D:\\zerodwnDatasets\\weekly_market_2017_2022.tsv',sep='\t')

# %%
dataSet=dataSet.dropna()

# %%
dataSet.shape
# Out:
# (557, 98)

# %%
dataSet.head(5)
# Out:
#         region_id  region_type_id                region_name region_type  \
# 317124      47664              -2      Warren, MI metro area       metro
# 325125      24660              -2  Greensboro, NC metro area       metro
# 325236      24660              -2  Greensboro, NC metro area       metro
# 339629      43060              -2     Shawnee, OK metro area       metro
# 412906      19804              -2     Detroit, MI metro area       metro
#
#        period_begin  period_end duration  total_homes_sold  \
# 317124   2022-02-07  2022-03-06  4 weeks            2511.0
# 325125   2022-02-14  2022-03-13  4 weeks             798.0
# 325236   2022-02-21  2022-03-20  4 weeks             819.0
# 339629   2022-02-21  2022-03-20  4 weeks              83.0
# 412906   2022-02-21  2022-03-20  4 weeks            1379.0
#
#         total_homes_sold_yoy  average_homes_sold  ...  \
# 317124             -0.063060               627.0  ...
# 325125             -0.150160               199.0  ...
# ...

# %%
dataSet.to_csv('HousingData.csv')

# %%
housingData=pd.read_csv('HousingData.csv')

housingData.head(5)
# Out:
#    Unnamed: 0  region_id  region_type_id                region_name  \
# 0      317124      47664              -2      Warren, MI metro area
# 1      325125      24660              -2  Greensboro, NC metro area
# 2      325236      24660              -2  Greensboro, NC metro area
# 3      339629      43060              -2     Shawnee, OK metro area
# 4      412906      19804              -2     Detroit, MI metro area
#
#   region_type period_begin  period_end duration  total_homes_sold  \
# 0       metro   2022-02-07  2022-03-06  4 weeks            2511.0
# 1       metro   2022-02-14  2022-03-13  4 weeks             798.0
# 2       metro   2022-02-21  2022-03-20  4 weeks             819.0
# 3       metro   2022-02-21  2022-03-20  4 weeks              83.0
# 4       metro   2022-02-21  2022-03-20  4 weeks            1379.0
#
#    total_homes_sold_yoy  ...  average_adjustment_average_homes_sold  \
# 0             -0.063060  ...                               1.013756
# ...
